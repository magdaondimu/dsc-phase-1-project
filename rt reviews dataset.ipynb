# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
rt_reviews = pd.read_csv(r"C:\Users\Magda\OneDrive\Documents\Flatiron\rt.reviews.tsv", sep='\t', encoding='latin1')
rt_reviews
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
rt_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
rt_reviews.describe()
# Out:
#                  id    top_critic
# count  54432.000000  54432.000000
# mean    1045.706882      0.240594
# std      586.657046      0.427448
# min        3.000000      0.000000
# 25%      542.000000      0.000000
# 50%     1083.000000      0.000000
# 75%     1541.000000      0.000000
# max     2000.000000      1.000000

# %%
rt_reviews.isnull().values.any()
# Out:
# True

# %%
rt_reviews.isnull().sum().sum()
# Out:
# 22111

# %%
rt_reviews.fillna(method="ffill", inplace=True)
rt_reviews
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    3/5  rotten
# 2         3  ... life lived in a bubble in financial dealin...    3/5   fresh
# 3         3  Continuing along a line introduced in last yea...    3/5   fresh
# 4         3             ... a perverse twist on neorealism...     3/5   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...  1.5/5   fresh
# 54428  2000  The real charm of this trifle is the deadpan c...    1/5  rotten
# 54429  2000  The real charm of this trifle is the deadpan c...    2/5  rotten
# 54430  2000  The real charm of this trifle is the deadpan c...  2.5/5  rotten
# 54431  2000  The real charm of this trifle is the deadpan c...    3/5   fresh
#
# ...

# %%
rt_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      54432 non-null  object
#  2   rating      54432 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      54432 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54432 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
rt_reviews['date'].dtype
# Out:
# dtype('O')

# %%
rt_reviews['date']
# Out:
# 0         November 10, 2018
# 1              May 23, 2018
# 2           January 4, 2018
# 3         November 16, 2017
# 4          October 12, 2017
#                 ...
# 54427    September 24, 2002
# 54428    September 21, 2005
# 54429         July 17, 2005
# 54430     September 7, 2003
# 54431     November 12, 2002
# Name: date, Length: 54432, dtype: object

# %%
rt_reviews['date'] = pd.to_datetime(rt_reviews['date'])
rt_reviews['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
rt_reviews['date'] = pd.to_datetime(rt_reviews['date']).dt.year
rt_reviews['date']
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2017
# 4        2017
#          ...
# 54427    2002
# 54428    2005
# 54429    2005
# 54430    2003
# 54431    2002
# Name: date, Length: 54432, dtype: int32

# %%
rt_reviews
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    3/5  rotten
# 2         3  ... life lived in a bubble in financial dealin...    3/5   fresh
# 3         3  Continuing along a line introduced in last yea...    3/5   fresh
# 4         3             ... a perverse twist on neorealism...     3/5   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...  1.5/5   fresh
# 54428  2000  The real charm of this trifle is the deadpan c...    1/5  rotten
# 54429  2000  The real charm of this trifle is the deadpan c...    2/5  rotten
# 54430  2000  The real charm of this trifle is the deadpan c...  2.5/5  rotten
# 54431  2000  The real charm of this trifle is the deadpan c...    3/5   fresh
#
# ...
